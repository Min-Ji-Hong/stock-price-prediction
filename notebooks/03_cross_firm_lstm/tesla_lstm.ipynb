# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
tsla = yf.download("TSLA", start="2015-01-01", end="2025-11-13")
tsla.head()
# Out:
# /tmp/ipython-input-3482032691.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tsla = yf.download("TSLA", start="2015-01-01", end="2025-11-13")
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           TSLA       TSLA       TSLA       TSLA      TSLA
# Date
# 2015-01-02  14.620667  14.883333  14.217333  14.858000  71466000
# 2015-01-05  14.006000  14.433333  13.810667  14.303333  80527500
# 2015-01-06  14.085333  14.280000  13.614000  14.004000  93928500
# 2015-01-07  14.063333  14.318667  13.985333  14.223333  44526000
# 2015-01-08  14.041333  14.253333  14.000667  14.187333  51637500

# %%
#Add columns
def column_add(df)->pd.DataFrame:
    df['Returns'] = df['Close'].pct_change()
    df['LogReturns'] = np.log(df['Close'] / df['Close'].shift(1))
    df['MA20'] = df['Close'].rolling(window=20).mean()
    df['MA60'] = df['Close'].rolling(window=60).mean()
    df['Volatility20'] = df['Returns'].rolling(window=20).std()
    df['Volatility'] = df['Volatility20']* np.sqrt(252)  #Annualized Volatility
    return df

# %%
column_add(tsla)
tsla.head()
# Out:
# Price           Close       High        Low       Open    Volume   Returns  \
# Ticker           TSLA       TSLA       TSLA       TSLA      TSLA
# Date
# 2015-01-02  14.620667  14.883333  14.217333  14.858000  71466000       NaN
# 2015-01-05  14.006000  14.433333  13.810667  14.303333  80527500 -0.042041
# 2015-01-06  14.085333  14.280000  13.614000  14.004000  93928500  0.005664
# 2015-01-07  14.063333  14.318667  13.985333  14.223333  44526000 -0.001562
# 2015-01-08  14.041333  14.253333  14.000667  14.187333  51637500 -0.001564
#
# Price      LogReturns MA20 MA60 Volatility20 Volatility
# Ticker
# Date
# 2015-01-02        NaN  NaN  NaN          NaN        NaN
# 2015-01-05  -0.042950  NaN  NaN          NaN        NaN
# 2015-01-06   0.005648  NaN  NaN          NaN        NaN
# 2015-01-07  -0.001563  NaN  NaN          NaN        NaN
# 2015-01-08  -0.001566  NaN  NaN          NaN        NaN

# %%
###나머지 관련주 - EV Sector
#1. Nio Inc. (NIO)
nio = yf.download("NIO", start="2015-01-01", end="2025-11-13")
column_add(nio)

#2. ChargePoint Holdings
chpt = yf.download("CHPT", start="2015-01-01", end="2025-11-13")
column_add(chpt)
#3. Volkswagen AG
vwagy = yf.download("VWAGY", start="2015-01-01", end="2025-11-13")
column_add(vwagy)

#6. TM(Toyota Motor)
tm = yf.download("TM", start="2015-01-01", end="2025-11-13")
column_add(tm)

# byd: BYD Company
byd = yf.download("1211.HK", start="2015-01-01", end="2025-11-13")
column_add(byd)
# Out:
# /tmp/ipython-input-3126502926.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nio = yf.download("NIO", start="2015-01-01", end="2025-11-13")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-3126502926.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   chpt = yf.download("CHPT", start="2015-01-01", end="2025-11-13")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-3126502926.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   vwagy = yf.download("VWAGY", start="2015-01-01", end="2025-11-13")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-3126502926.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tm = yf.download("TM", start="2015-01-01", end="2025-11-13")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-3126502926.py:18: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   byd = yf.download("1211.HK", start="2015-01-01", end="2025-11-13")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume  \
# Ticker         1211.HK     1211.HK     1211.HK     1211.HK   1211.HK
# Date
# 2015-01-02   10.021317   10.037099    9.547868    9.737248  24822066
# 2015-01-05   10.021317   10.116006    9.800375   10.052879  34120002
# 2015-01-06   10.068662   10.100224    9.863500   10.021317  17734590
# 2015-01-07    9.216455   10.037100    9.090204   10.037100  39908772
# 2015-01-08    9.326927    9.547869    9.279582    9.374271  19330665
# ...                ...         ...         ...         ...       ...
# 2025-11-06   97.650002   97.800003   94.150002   94.650002  31445844
# 2025-11-07   97.900002   98.750000   96.900002   97.300003  20328719
# 2025-11-10  101.800003  102.900002   97.900002   97.900002  33899737
# 2025-11-11  101.300003  103.300003  100.599998  102.900002  14575190
# 2025-11-12  100.500000  101.300003   99.500000  101.300003  16213089
#
# Price        Returns LogReturns      MA20        MA60 Volatility20 Volatility
# Ticker
# Date
# 2015-01-02       NaN        NaN       NaN         NaN          NaN        NaN
# 2015-01-05  0.000000   0.000000       NaN         NaN          NaN        NaN
# 2015-01-06  0.004724   0.004713       NaN         NaN          NaN        NaN
# 2015-01-07 -0.084639  -0.088437       NaN         NaN          NaN        NaN
# 2015-01-08  0.011986   0.011915       NaN         NaN          NaN        NaN
# ...              ...        ...       ...         ...          ...        ...
# 2025-11-06  0.023585   0.023311  103.6775  108.094167     0.018257   0.289817
# 2025-11-07  0.002560   0.002557  103.0625  107.870833     0.018203   0.288970
# 2025-11-10  0.039837   0.039064  102.7425  107.650833     0.020585   0.326780
# 2025-11-11 -0.004912  -0.004924  102.4925  107.442500     0.020302   0.322278
# 2025-11-12 -0.007897  -0.007929  102.2475  107.237500     0.020293   0.322138
#
# [2676 rows x 11 columns]

# %%
##영업일 기준(5일) resampling
nio = nio.dropna(how='all').asfreq('B').ffill()
print(f"nio len: {nio.shape[0]}")

chpt = chpt.dropna(how='all').asfreq('B').ffill()
print(f"chpt len: {chpt.shape[0]}")

vwagy = vwagy.dropna(how='all').asfreq('B').ffill()
print(f"vwagy len: {vwagy.shape[0]}")

tm = tm.dropna(how='all').asfreq('B').ffill()
print(f"tm len: {tm.shape[0]}")

byd = byd.dropna(how='all').asfreq('B').ffill()
print(f"byd len: {byd.shape[0]}")
# Out:
# nio len: 1871
# chpt len: 1608
# vwagy len: 2834
# tm len: 2834
# byd len: 2834

# %%
### Intersection of Dates
def align_dates(df1, name1, df2=tsla, name2='tsla'):
    # 필요한 컬럼만 추출하고 common dates로 inner join
    a = df1[['LogReturns']].dropna()
    b = df2[['Close','LogReturns']].dropna()#tsla는 close price도 필요
    df_merged = pd.concat([a, b], axis=1, join='inner', keys=[name1, name2])
    df_merged.columns = [f'{name1}_LogReturns',f'{name2}_Close', f'{name2}_LogReturns']
    return df_merged

# %%
related = {}
stock_tickers = ['nio','chpt','vwagy','tm','byd']

for name in stock_tickers:
    df = globals().get(name)
    if df is None:
        print(f"{name} not found")
        related[name] = None
    else:
        related[name] = df if not df.empty else None

# 확인
for k, v in related.items():
    print(k, '->', 'empty' if v is None else f'df shape {v.shape}')
# Out:
# nio -> df shape (1871, 11)
# chpt -> df shape (1608, 11)
# vwagy -> df shape (2834, 11)
# tm -> df shape (2834, 11)
# byd -> df shape (2834, 11)

# %%
merged_df = {}
for name, df in related.items():
    merged = align_dates(df1=df, name1=name)
    merged_df[f'{name}_tsla'] = merged
    print(f"Merged {name} with tsla: shape {merged.shape}")

#check
for k, v in merged_df.items():
    print(k, '->', 'empty' if v is None else f'df shape {v.shape}')
# Out:
# Merged nio with tsla: shape (1802, 3)
# Merged chpt with tsla: shape (1549, 3)
# Merged vwagy with tsla: shape (2732, 3)
# Merged tm with tsla: shape (2732, 3)
# Merged byd with tsla: shape (2732, 3)
# nio_tsla -> df shape (1802, 3)
# chpt_tsla -> df shape (1549, 3)
# vwagy_tsla -> df shape (2732, 3)
# tm_tsla -> df shape (2732, 3)
# byd_tsla -> df shape (2732, 3)

# %%
print(merged_df['byd_tsla'].head())
# Out:
#             byd_LogReturns  tsla_Close  tsla_LogReturns
# Date
# 2015-01-05        0.000000   14.006000        -0.042950
# 2015-01-06        0.004713   14.085333         0.005648
# 2015-01-07       -0.088437   14.063333        -0.001563
# 2015-01-08        0.011915   14.041333        -0.001566
# 2015-01-09        0.011775   13.777333        -0.018981

# %%
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np

scaler = StandardScaler()
for name, df in merged_df.items():
    df['tsla_LogReturns2'] = df['tsla_LogReturns']#y label로 쓰일 컬럼 복사
    df.iloc[:,[0,2]] = scaler.fit_transform(df.iloc[:,[0,2]])
    if(name=='byd_tsla'):
      print(df.head())

##merged_df preprocessing
'''
1. standard scaling 적용: 종목 [A], TSLA의 log return->모델의 input feature로 사용될 것이므로
2. tsla_log return(scaling 적용 x ground truth)->모델의 output으로 사용될 것이므로
3. tsla close price(최종적으로 예측하고자 하는 것)
'''
# Out:
#             byd_LogReturns  tsla_Close  tsla_LogReturns  tsla_LogReturns2
# Date
# 2015-01-05       -0.037923   14.006000        -1.214856         -0.042950
# 2015-01-06        0.118000   14.085333         0.121244          0.005648
# 2015-01-07       -2.963547   14.063333        -0.077016         -0.001563
# 2015-01-08        0.356245   14.041333        -0.077082         -0.001566
# 2015-01-09        0.351600   13.777333        -0.555867         -0.018981
# '\n1. standard scaling 적용: 종목 [A], TSLA의 log return->모델의 input feature로 사용될 것이므로 \n2. tsla_log return(scaling 적용 x ground truth)->모델의 output으로 사용될 것이므로\n3. tsla close price(최종적으로 예측하고자 하는 것)\n'

# %%
def generate_dataset(df, input_idx, target_idx, window_size, test_n):
    x, y = [], []

    for i in range(len(df) - window_size):
        x.append(df.iloc[i:i+window_size, input_idx].values)
        y.append(df.iloc[i+window_size, target_idx])

    x = np.array(x)
    y = np.array(y)

    # -----------------------------
    # Time-based Train / Test split
    # -----------------------------
    test_idx = len(df) - test_n
    split_point = test_idx - window_size

    x_train = x[:split_point]
    y_train = y[:split_point]

    x_test = x[split_point:]
    y_test = y[split_point:]

    # -----------------------------
    # Train / Validation split
    # -----------------------------
    x_train, x_val, y_train, y_val = train_test_split(
        x_train, y_train,
        test_size=0.1,
        shuffle=False   # 시계열이므로 False
    )

    print(f"# Train: {y_train.shape[0]}")
    print(f"# Val:   {y_val.shape[0]}")
    print(f"# Test:  {y_test.shape[0]}")
    print(f"# Input shape: {x_train.shape[1:]}")

    return x_train, y_train, x_val, y_val, x_test, y_test


# 1. LSTM 모델

def build_lstm(input_shape):
    model = keras.Sequential([
        keras.layers.LSTM(
            64, activation='tanh',
            input_shape=input_shape,
            return_sequences=False
        ),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(1)
    ])
    model.compile(
        loss='mae',
        optimizer=Adam(0.001),
        metrics=['mae']
    )
    return model

# %%
def run_experiment(df, input_idx, target_idx, window_size):

    print("\n====================================")
    print(f" Running Window Size = {window_size}")
    print("====================================\n")

    # Dataset 생성
    test_n = int(0.2 * len(df))

    x_train, y_train, x_val, y_val, x_test, y_test = generate_dataset(
        df, input_idx, target_idx, window_size, test_n
    )

    # Model
    model = build_lstm((x_train.shape[1], x_train.shape[2]))

    checkpoint_path = f"./best_lstm_cols{input_idx}_ws{window_size}.weights.h5"

    cbk = keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_path,
        save_weights_only=True,
        monitor="val_mae",
        mode="min",
        save_best_only=True
    )

    es = keras.callbacks.EarlyStopping(
    monitor="val_mae",
    patience=50,
    restore_best_weights=True
)


    # -----------------------------
    # Train
    # -----------------------------
    history = model.fit(
        x_train, y_train,
        epochs=200,
        batch_size=32,
        validation_data=(x_val, y_val),
        callbacks=[cbk, es],
        verbose=1
    )

    # -----------------------------
    # Test
    # -----------------------------
    model.load_weights(checkpoint_path)
    loss, mae = model.evaluate(x_test, y_test, verbose=0)
    print("\nTest MAE (log return):", mae)

    y_pred = model.predict(x_test).flatten()

    # Date index 추출
    test_idx = len(df) - test_n
    split_point = test_idx - window_size
    test_start_index = split_point + window_size

    date_index = df.index[
        test_start_index : test_start_index + len(y_test)
    ]
    # log return → TSLA Close Price 복원

    tsla_close_prev = df.iloc[
    test_start_index - 1 : test_start_index + len(y_test) - 1,
    1   # tsla_close column index
    ].values


    y_test_price = df.iloc[test_start_index:test_start_index+len(y_test),1].values #y_test: g.t tsla close price for test set->1이 tsla_close price column
    y_pred_price = tsla_close_prev * np.exp(y_pred) #이전 tsla close price * exp(predicted log return)->predicted close price

    # Plot
    plt.figure(figsize=(12, 6))
    plt.plot(date_index, y_test_price, label="True TSLA Close", color="orange")
    plt.plot(date_index, y_pred_price, label="Predicted TSLA Close", color="skyblue")
    plt.title(f"TSLA Close Prediction (Window = {window_size})")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

    # Metrics
    mae_price = np.mean(np.abs(y_test_price - y_pred_price))
    rmse_price = np.sqrt(np.mean((y_test_price - y_pred_price)**2))
    direction_acc = np.mean(
    np.sign(np.diff(y_test_price)) == np.sign(np.diff(y_pred_price))
  )
    mape = np.mean(np.abs((y_test_price - y_pred_price) / y_test_price)) * 100


    result = {
        "MAE_price": mae_price,
        "RMSE_price": rmse_price,
        "MAPE_price": mape,
        "direction_acc": direction_acc
    }


    print("\nMetrics:")
    for k, v in result.items():
        print(f"{k}: {v:.4f}")

    return result

# %% [markdown]
# ## 세 가지 방식으로 시도

# %% [markdown]
# ## 1. correlated된 두 종목 함께 사용
# - 두 종목(TSLA, 다른 하나)의 log return->TSLA log return 예측->예측된 log return 기반으로 TSLA close price 예측->metric 계산
# - setting: window = 20 (rolling correlation 시 나쁘지 않게 나와서 window size는 20으로 설정)
#
# **결과:**
# 1. vwagy & tsla
#
# MAE_price: 7.8688
# RMSE_price: 10.9339
# MAPE_price: 2.8271
# direction_acc: 0.4807
#
# 2. tm & tsla
#
# MAE_price: 7.8324
# RMSE_price: 10.8754
# MAPE_price: 2.8164
# direction_acc: 0.4899

# %%
results = {}
ws = 20
df_names = ['vwagy_tsla','tm_tsla']

## tsla+다른 한 종목의 log return 2개 사용해서->tsla의 log return 예측
for name in df_names:
  results[ws] = run_experiment(merged_df[name],[0,2],3,ws)
  print("\n============== Summary ==============")
  for ws, mae in results.items():
      print(f"Window Size 20 → Test MAE = {mae}")
  print("=====================================\n")
# Out:
# ====================================
#  Running Window Size = 20
# ====================================
#
# # Train: 1949
# # Val:   217
# # Test:  546
# # Input shape: (20, 2)
# Epoch 1/200
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0406 - mae: 0.0406 - val_loss: 0.0296 - val_mae: 0.0296
# Epoch 2/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0273 - mae: 0.0273 - val_loss: 0.0287 - val_mae: 0.0287
# Epoch 3/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0258 - mae: 0.0258 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 4/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 5/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0258 - mae: 0.0258 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 6/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 7/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 8/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 9/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 10/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 11/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 12/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 13/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 14/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 15/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 16/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 17/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0256 - mae: 0.0256 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 18/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 19/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 20/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 21/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 22/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 23/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 24/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 25/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 26/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 27/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 28/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 29/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 30/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 31/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 32/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 33/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 34/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 35/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0254 - mae: 0.0254 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 36/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 37/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 38/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 39/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 40/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 41/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 42/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 43/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 44/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 45/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 46/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 47/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 48/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 49/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 50/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 51/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 52/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0292 - val_mae: 0.0292
#
# Test MAE (log return): 0.028218979015946388
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Metrics:
# MAE_price: 7.8688
# RMSE_price: 10.9339
# MAPE_price: 2.8271
# direction_acc: 0.4807
#
# ============== Summary ==============
# Window Size 20 → Test MAE = {'MAE_price': np.float64(7.868802060706594), 'RMSE_price': np.float64(10.933911815538666), 'MAPE_price': np.float64(2.8270737782782493), 'direction_acc': np.float64(0.48073394495412847)}
# =====================================
#
#
# ====================================
#  Running Window Size = 20
# ====================================
#
# # Train: 1949
# # Val:   217
# # Test:  546
# # Input shape: (20, 2)
# Epoch 1/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0424 - mae: 0.0424 - val_loss: 0.0307 - val_mae: 0.0307
# Epoch 2/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0272 - mae: 0.0272 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 3/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0258 - mae: 0.0258 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 4/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 5/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 6/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 7/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 8/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 9/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 10/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 11/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 12/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 13/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 14/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 15/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 16/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0251 - mae: 0.0251 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 17/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 18/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 19/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 20/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 21/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 22/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 23/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 24/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 25/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 26/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 27/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 28/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 29/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0257 - mae: 0.0257 - val_loss: 0.0294 - val_mae: 0.0294
# Epoch 30/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0254 - mae: 0.0254 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 31/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 32/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 33/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 34/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 35/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 36/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 37/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 38/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 39/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 40/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 41/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 42/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 43/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 44/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 45/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 46/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 47/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 48/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0251 - mae: 0.0251 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 49/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 50/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0229 - mae: 0.0229 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 51/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 52/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 53/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 54/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 55/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 56/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 57/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 58/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 59/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 60/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 61/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 62/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 63/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 64/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 65/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 66/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 67/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 68/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 69/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0234 - mae: 0.0234 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 70/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 71/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 72/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 73/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 74/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 75/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 76/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 77/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 78/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 79/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 80/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 81/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 82/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0288 - val_mae: 0.0288
# Epoch 83/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 84/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 85/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 86/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 87/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 88/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 89/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 90/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 91/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 92/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 93/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 94/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 95/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0288 - val_mae: 0.0288
# Epoch 96/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0288 - val_mae: 0.0288
# Epoch 97/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 98/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0288 - val_mae: 0.0288
# Epoch 99/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 100/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 101/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 102/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 103/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 104/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 105/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 106/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 107/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 108/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 109/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 110/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 111/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0224 - mae: 0.0224 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 112/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 113/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 114/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0234 - mae: 0.0234 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 115/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 116/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 117/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0288 - val_mae: 0.0288
# Epoch 118/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 119/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0288 - val_mae: 0.0288
# Epoch 120/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 121/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 122/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0288 - val_mae: 0.0288
# Epoch 123/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 124/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0229 - mae: 0.0229 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 125/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0288 - val_mae: 0.0288
# Epoch 126/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 127/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 128/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 129/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 130/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 131/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0234 - mae: 0.0234 - val_loss: 0.0294 - val_mae: 0.0294
# Epoch 132/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 133/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 134/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0303 - val_mae: 0.0303
# Epoch 135/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 136/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 137/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0294 - val_mae: 0.0294
# Epoch 138/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0232 - mae: 0.0232 - val_loss: 0.0301 - val_mae: 0.0301
# Epoch 139/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0234 - mae: 0.0234 - val_loss: 0.0297 - val_mae: 0.0297
# Epoch 140/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0294 - val_mae: 0.0294
# Epoch 141/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0232 - mae: 0.0232 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 142/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 143/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0232 - mae: 0.0232 - val_loss: 0.0295 - val_mae: 0.0295
# Epoch 144/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0289 - val_mae: 0.0289
# Epoch 145/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0301 - val_mae: 0.0301
# Epoch 146/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0311 - val_mae: 0.0311
# Epoch 147/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0299 - val_mae: 0.0299
# Epoch 148/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0296 - val_mae: 0.0296
# Epoch 149/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0301 - val_mae: 0.0301
# Epoch 150/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0232 - mae: 0.0232 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 151/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0328 - val_mae: 0.0328
# Epoch 152/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0303 - val_mae: 0.0303
# Epoch 153/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0299 - val_mae: 0.0299
# Epoch 154/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0313 - val_mae: 0.0313
# Epoch 155/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0300 - val_mae: 0.0300
# Epoch 156/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0297 - val_mae: 0.0297
# Epoch 157/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0234 - mae: 0.0234 - val_loss: 0.0311 - val_mae: 0.0311
# Epoch 158/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0315 - val_mae: 0.0315
# Epoch 159/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0299 - val_mae: 0.0299
# Epoch 160/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0230 - mae: 0.0230 - val_loss: 0.0309 - val_mae: 0.0309
# Epoch 161/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0312 - val_mae: 0.0312
# Epoch 162/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0297 - val_mae: 0.0297
# Epoch 163/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0229 - mae: 0.0229 - val_loss: 0.0307 - val_mae: 0.0307
# Epoch 164/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0300 - val_mae: 0.0300
# Epoch 165/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0302 - val_mae: 0.0302
# Epoch 166/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0304 - val_mae: 0.0304
# Epoch 167/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0312 - val_mae: 0.0312
#
# Test MAE (log return): 0.028112880885601044
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Metrics:
# MAE_price: 7.8324
# RMSE_price: 10.8754
# MAPE_price: 2.8164
# direction_acc: 0.4899
#
# ============== Summary ==============
# Window Size 20 → Test MAE = {'MAE_price': np.float64(7.832388655436045), 'RMSE_price': np.float64(10.875427288133103), 'MAPE_price': np.float64(2.816434230317625), 'direction_acc': np.float64(0.48990825688073397)}
# =====================================

# %% [markdown]
# ## 2. 다른 종목만 사용해서 tsla 예측
# **결과:**
# 1. vwagy -> tsla
#
# MAE_price: 7.8453
# RMSE_price: 10.9340
# MAPE_price: 2.8115
# direction_acc: 0.4826
#
# 2. tm -> tsla
#
# MAE_price: 7.8546
# RMSE_price: 10.9334
# MAPE_price: 2.8177
# direction_acc: 0.4807

# %%
# 다른 종목 log return->tsla log return->tesla close price
for name in df_names:
  results[ws] = run_experiment(merged_df[name],[0],3,ws)
  print("\n============== Summary ==============")
  for ws, mae in results.items():
      print(f"Window Size 20 → Test MAE = {mae}")
  print("=====================================\n")
# Out:
# ====================================
#  Running Window Size = 20
# ====================================
#
# # Train: 1949
# # Val:   217
# # Test:  546
# # Input shape: (20, 1)
# Epoch 1/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0354 - mae: 0.0354 - val_loss: 0.0294 - val_mae: 0.0294
# Epoch 2/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 3/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 4/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 5/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 6/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 7/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0251 - mae: 0.0251 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 8/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 9/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 10/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 11/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0256 - mae: 0.0256 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 12/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 13/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 14/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0234 - mae: 0.0234 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 15/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 16/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 17/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 18/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 19/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 20/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 21/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 22/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 23/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 24/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 25/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 26/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 27/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0254 - mae: 0.0254 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 28/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 29/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 30/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 31/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 32/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 33/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 34/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 35/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 36/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 37/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 38/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 39/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 40/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 41/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 42/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 43/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 44/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 45/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 46/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 47/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 48/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 49/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 50/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 51/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 52/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 53/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0292 - val_mae: 0.0292
#
# Test MAE (log return): 0.028125660493969917
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Metrics:
# MAE_price: 7.8453
# RMSE_price: 10.9340
# MAPE_price: 2.8115
# direction_acc: 0.4826
#
# ============== Summary ==============
# Window Size 20 → Test MAE = {'MAE_price': np.float64(7.84532491937613), 'RMSE_price': np.float64(10.933969010453467), 'MAPE_price': np.float64(2.811459309432334), 'direction_acc': np.float64(0.48256880733944957)}
# =====================================
#
#
# ====================================
#  Running Window Size = 20
# ====================================
#
# # Train: 1949
# # Val:   217
# # Test:  546
# # Input shape: (20, 1)
# Epoch 1/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0302 - mae: 0.0302 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 2/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 3/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 4/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 5/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 6/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 7/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 8/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 9/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 10/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 11/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 12/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0251 - mae: 0.0251 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 13/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 14/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 15/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0256 - mae: 0.0256 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 16/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 17/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 18/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 19/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 20/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 21/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 22/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 23/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 24/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 25/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 26/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0234 - mae: 0.0234 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 27/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 28/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 29/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 30/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 31/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 32/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 33/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 34/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 35/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 36/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 37/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 38/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 39/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 40/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 41/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 42/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 43/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0234 - mae: 0.0234 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 44/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 45/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 46/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 47/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 48/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 49/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 50/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 51/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 52/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 53/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0254 - mae: 0.0254 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 54/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 55/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 56/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 57/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 58/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 59/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 60/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 61/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0255 - mae: 0.0255 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 62/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 63/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 64/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 65/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 66/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 67/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0294 - val_mae: 0.0294
# Epoch 68/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0251 - mae: 0.0251 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 69/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 70/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 71/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 72/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0232 - mae: 0.0232 - val_loss: 0.0292 - val_mae: 0.0292
#
# Test MAE (log return): 0.028178559616208076
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Metrics:
# MAE_price: 7.8546
# RMSE_price: 10.9334
# MAPE_price: 2.8177
# direction_acc: 0.4807
#
# ============== Summary ==============
# Window Size 20 → Test MAE = {'MAE_price': np.float64(7.854557300307953), 'RMSE_price': np.float64(10.933449129376191), 'MAPE_price': np.float64(2.817657364921298), 'direction_acc': np.float64(0.48073394495412847)}
# =====================================

# %% [markdown]
# ## 3. tsla 단일 데이터로 tsla 예측
# **결과:**
#
# MAE_price: 7.8407
# RMSE_price: 10.9309
# MAPE_price: 2.8169
# direction_acc: 0.4789

# %%
##tsla log return->tsla log return->tsla close price: 즉, 주가 단일 데이터 사용했을 때(baseline)
results[ws] = run_experiment(merged_df['vwagy_tsla'],[2],3,ws)
print("\n============== Summary ==============")
for ws, mae in results.items():
    print(f"Window Size 20 → Test MAE = {mae}")
print("=====================================\n")
# Out:
# ====================================
#  Running Window Size = 20
# ====================================
#
# # Train: 1949
# # Val:   217
# # Test:  546
# # Input shape: (20, 1)
# Epoch 1/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0342 - mae: 0.0342 - val_loss: 0.0295 - val_mae: 0.0295
# Epoch 2/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0288 - val_mae: 0.0288
# Epoch 3/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 4/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 5/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 6/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 7/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0293 - val_mae: 0.0293
# Epoch 8/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 9/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 10/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 11/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 12/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 13/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 14/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 15/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 16/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 17/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 18/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 19/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 20/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 21/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 22/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 23/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 24/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0257 - mae: 0.0257 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 25/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 26/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0251 - mae: 0.0251 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 27/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 28/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 29/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 30/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 31/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 32/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0249 - mae: 0.0249 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 33/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 34/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 35/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0239 - mae: 0.0239 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 36/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 37/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 38/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 39/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 40/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0250 - mae: 0.0250 - val_loss: 0.0290 - val_mae: 0.0290
# Epoch 41/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238 - mae: 0.0238 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 42/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 43/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0251 - mae: 0.0251 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 44/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 45/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0294 - val_mae: 0.0294
# Epoch 46/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 47/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0255 - mae: 0.0255 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 48/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 49/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 50/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.0248 - val_loss: 0.0291 - val_mae: 0.0291
# Epoch 51/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0244 - mae: 0.0244 - val_loss: 0.0292 - val_mae: 0.0292
# Epoch 52/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0255 - mae: 0.0255 - val_loss: 0.0291 - val_mae: 0.0291
#
# Test MAE (log return): 0.028106508776545525
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Metrics:
# MAE_price: 7.8407
# RMSE_price: 10.9309
# MAPE_price: 2.8169
# direction_acc: 0.4789
#
# ============== Summary ==============
# Window Size 20 → Test MAE = {'MAE_price': np.float64(7.840722309147138), 'RMSE_price': np.float64(10.930912107209371), 'MAPE_price': np.float64(2.816863686659145), 'direction_acc': np.float64(0.47889908256880737)}
# =====================================

# %% [markdown]
# ## **Final Summary**
#
# **1. tsla->tsla 예측(baseline)**
#
# MAE_price: 7.8407
# RMSE_price: 10.9309
# MAPE_price: 2.8169
# direction_acc: 0.4789
#
# **2. 다른 종목->tsla 예측**
#
# (1). vwagy -> tsla
#
# MAE_price: 7.8453
# RMSE_price: 10.9340
# MAPE_price: 2.8115
# direction_acc: 0.4826
#
# (2). tm -> tsla
#
# MAE_price: 7.8546
# RMSE_price: 10.9334
# MAPE_price: 2.8177
# direction_acc: 0.4807
#
# **3, 두 종목 모두 이용(tsla+다른 종목 하나)**
#
# (1). vwagy & tsla
#
# MAE_price: 7.8688
# RMSE_price: 10.9339
# MAPE_price: 2.8271
# direction_acc: 0.4807
#
# (2). tm & tsla
#
# MAE_price: 7.8324
# RMSE_price: 10.8754
# MAPE_price: 2.8164
# direction_acc: 0.4899
#
# -> 결론적으로 세 방식 모두 성능에서 차이는 거의 없지만 그래도 상관성이 있는 두 종목을 함께 이용하여 예측했을 시 test set에 대한 성능이 가장 좋아질 가능성을 볼 수 있음->tm&tsla가 best model?
